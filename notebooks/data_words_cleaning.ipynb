# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns
import pprint
import re

# %%
data = pd.read_csv("Hotel_reviews.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   Hotel_Address                               515738 non-null  object
#  1   Additional_Number_of_Scoring                515738 non-null  int64
#  2   Review_Date                                 515738 non-null  object
#  3   Average_Score                               515738 non-null  float64
#  4   Hotel_Name                                  515738 non-null  object
#  5   Reviewer_Nationality                        515738 non-null  object
#  6   Negative_Review                             515738 non-null  object
#  7   Review_Total_Negative_Word_Counts           515738 non-null  int64
#  8   Total_Number_of_Reviews                     515738 non-null  int64
#  9   Positive_Review                             515738 non-null  object
#  10  Review_Total_Positive_Word_Counts           515738 non-null  int64
#  11  Total_Number_of_Reviews_Reviewer_Has_Given  515738 non-null  int64
#  12  Reviewer_Score                              515738 non-null  float64
#  13  Tags                                        515738 non-null  object
#  14  days_since_review                           515738 non-null  object
#  15  lat                                         512470 non-null  float64
#  16  lng                                         512470 non-null  float64
# dtypes: float64(4), int64(5), object(8)
# memory usage: 66.9+ MB

# %%
data.shape
# Out:
# (515738, 17)

# %%
#initial assessment
# coloumns are arranged badly
# at this context we are focsed on the reviews and their corresponding ratings, and we may not need to account for the reviewer's Nationality 
# we don't need the fields "days_since_review","lat","lng" --> we remove them from our dataframe
# additional number of scoring is really vague value and also doesnt amoun to much for our analysis

# %%
df = data.copy()

# %%
df = df.drop(['Hotel_Address','Additional_Number_of_Scoring','Reviewer_Nationality','Reviewer_Score','days_since_review','lat','lng'], axis=1)

# %%
df.shape
# Out:
# (515738, 10)

# %%
#data cleaning
def header_names(df):
    numerical = df.select_dtypes(np.number)
    categorical = df.select_dtypes(object)
    
    numerical_df = numerical.rename(columns=str.lower)
    numerical_df.columns = numerical_df.columns.str.replace(' ', '_')
    numerical_df.drop_duplicates()
    numerical_df = numerical_df.round()
    numerical_df = numerical_df.astype(int)
    categorical_df = categorical.rename(columns=str.lower) 
    categorical_df.columns = categorical_df.columns.str.replace(' ', '_')
    categorical_df.drop_duplicates() 
       
    return numerical_df,categorical_df

# %%
num_df,cat_df = header_names(df)

# %%
# consider reviewer score, to the categorical and drop the rest

# %%
review_df = num_df[['average_score']]

# %%
final_df = pd.concat([cat_df, review_df],axis=1)

# %%
#column rearranging

# %%
final_df = final_df[['hotel_name', 'negative_review', 'positive_review', 'tags','average_score']]

# %%
#missing, nans and blank spaces elimination

# %%
def missing_and_nulls(final_df):
    display(final_df.isna().sum())
    #final_df.columns[final_df.isna().any()].tolist()
    print(final_df.isnull().nunique())

# %%
missing_and_nulls(final_df)
# Out:
# hotel_name         0
# negative_review    0
# positive_review    0
# tags               0
# average_score      0
# dtype: int64
# hotel_name         1
# negative_review    1
# positive_review    1
# tags               1
# average_score      1
# dtype: int64

# %%
final_df.shape
# Out:
# (515738, 5)

# %%
#df1 = final_df.dropna()

# %%
#df1.shape

# %%
#no null or missing values found. on with the next steps

# %% [markdown]
# #### Filtering the review

# %% [markdown]
# #### We have around 515k of reviews but according to the data not all of them are "helpful". Let's do some filtering.

# %%
#consider reviews those that are above 5
final_df = final_df[final_df['average_score'] >= 6]
final_df.shape
# Out:
# (515673, 5)

# %%
final_df.head(50)
# Out:
#      hotel_name                                    negative_review  \
# 0   Hotel Arena   I am so angry that i made this post available...
# 15   This hotel is awesome I took it sincirely bec...
# 16   Great onsite cafe Amazing building Park locat...
# 17   We loved the location of this hotel The fact ...
# 18   Public areas are lovely and the room was nice...
# 19   I liked the hotels history And for such an en...
# 20   Friendly staff OostPark a few yards away Good...
# 21   The breakfast was the only positive element o...
# 22   The location is good You need 15min to 20min ...
# 23   Bed was extremely comfy and the staff where w...
# 24   Lovely hotel with extremely comfortable huge ...
# 25   Great location in the park near museums and r...
# 26   The Hotel itself is in a lovely location a 5m...
# 27                 Great hotel original concept style
# 28   The hotel itself is beautiful restaurant is v...
# 29   The hotel is located in a beautiful old monas...
# 30   The staff were so friendly and helpful plus t...
# 31   Friendly staff The bar restaurant area is lov...
# 32                                        No Positive
# 33   The hotel is going through renovations and un...
# 34   The room was very big spacious The bath tub w...
# 35   Very nice hotel manager he upgraded us becaus...
# 36   the building meeting rooms modern style of my...
# 37   Very nice hotel located in a park Ca 30 minut...
# 38   The location was amazing the room was fantast...
# 39   Location on the park with easy access to tram...
# 40   The hotel is nicely localted directly within ...
# 41   Nice restaurant although felt breakfast was r...
# 42   Love the design of the renovated product The ...
# 43   Staff were amazing very very friendly and pro...
# 44    The brunch to purchase in the morning was good
# 45   The location of the hotel is super opening ou...
# 46                                        Massive bed
# 47   The hotel looks really impressive Set in a be...
# 48   The quality of the hotel was brilliant and ev...
# 49                                      clean and new
#
#                                                  tags  average_score
# 0   [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 1   [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 2   [' Leisure trip ', ' Family with young childre...              8
# 3   [' Leisure trip ', ' Solo traveler ', ' Duplex...              8
# 4   [' Leisure trip ', ' Couple ', ' Suite ', ' St...              8
# 5   [' Leisure trip ', ' Group ', ' Duplex Double ...              8
# 6   [' Leisure trip ', ' Group ', ' Duplex Twin Ro...              8
# 7   [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 8   [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 9   [' Leisure trip ', ' Couple ', ' Large King Ro...              8
# 10  [' Leisure trip ', ' Group ', ' Duplex Double ...              8
# 11  [' Business trip ', ' Solo traveler ', ' Duple...              8
# 12  [' Leisure trip ', ' Solo traveler ', ' Duplex...              8
# 13  [' Business trip ', ' Solo traveler ', ' Duple...              8
# 14  [' Leisure trip ', ' Family with young childre...              8
# 15  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 16  [' Leisure trip ', ' Family with young childre...              8
# 17  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 18  [' Business trip ', ' Group ', ' Duplex Double...              8
# 19  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 20  [' Leisure trip ', ' Travelers with friends ',...              8
# 21  [' Couple ', ' Duplex Double Room ', ' Stayed ...              8
# 22  [' Leisure trip ', ' Family with young childre...              8
# 23  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 24  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 25  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 26  [' Leisure trip ', ' Group ', ' Duplex Double ...              8
# 27  [' Business trip ', ' Solo traveler ', ' Duple...              8
# 28  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 29  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 30  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 31  [' Leisure trip ', ' Group ', ' 2 rooms ', ' S...              8
# 32  [' Leisure trip ', ' Group ', ' Duplex Twin Ro...              8
# 33  [' Leisure trip ', ' Family with young childre...              8
# 34  [' Leisure trip ', ' Family with young childre...              8
# 35  [' Leisure trip ', ' Couple ', ' Large King Ro...              8
# 36  [' Business trip ', ' Group ', ' Duplex Double...              8
# 37  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 38  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 39  [' Leisure trip ', ' Couple ', ' Duplex Twin R...              8
# 40  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
#
[' Leisure trip ', ' Couple ', ' Standard Doub...              8
# 515706  [' Leisure trip ', ' Group ', ' Superior Doubl...              8
# 515707  [' Leisure trip ', ' Group ', ' Standard Tripl...              8
# 515708  [' Leisure trip ', ' Family with older childre...              8
# 515709  [' Leisure trip ', ' Couple ', ' Standard Doub...              8
# 515710  [' Group ', ' Standard Double or Twin Room ', ...              8
# 515711  [' Leisure trip ', ' Couple ', ' Standard Doub...              8
# 515712  [' Leisure trip ', ' Couple ', ' Standard Doub...              8
# 515713  [' Leisure trip ', ' Family with young childre...              8
# 515714  [' Leisure trip ', ' Family with older childre...              8
# 515715  [' Leisure trip ', ' Group ', ' Standard Doubl...              8
# 515716  [' Leisure trip ', ' Couple ', ' Standard Doub...              8
# 515717  [' Leisure trip ', ' Family with young childre...              8
# 515718  [' Leisure trip ', ' Group ', ' Standard Tripl...              8
# 515719  [' Leisure trip ', ' Couple ', ' Standard Doub...              8
# 515720  [' Leisure trip ', ' Group ', ' Family Room ',...              8
# 515721  [' Leisure trip ', ' Solo traveler ', ' Superi...              8
# 515722  [' Business trip ', ' Solo traveler ', ' Stand...              8
# 515723  [' Leisure trip ', ' Group ', ' Standard Tripl...              8
# 515724  [' Leisure trip ', ' Family with young childre...              8
# 515725  [' Business trip ', ' Solo traveler ', ' Super...              8
# 515726  [' Business trip ', ' Couple ', ' Standard Dou...              8
# 515727  [' Leisure trip ', ' Couple ', ' Standard Doub...              8
# 515728  [' Leisure trip ', ' Couple ', ' Standard Doub...              8
# 515729  [' Leisure trip ', ' Couple ', ' Standard Doub...              8
# 515730  [' Leisure trip ', ' Family with young childre...              8
# 515731  [' Business trip ', ' Solo traveler ', ' Stand...              8
# 515732  [' Leisure trip ', ' Family with young childre...              8
# 515733  [' Leisure trip ', ' Family with older childre...              8
# 515734  [' Leisure trip ', ' Family with young childre...              8
# 515735  [' Leisure trip ', ' Family with older childre...              8
# 515736  [' Leisure trip ', ' Group ', ' Standard Tripl...              8
# 515737  [' Leisure trip ', ' Family with young childre...              8

# %%
final_df.shape
# Out:
# (515673, 5)

# %%
'''
Assumptions:
1. more words in the positive and the negative coloumns the better, since they're almost legitimate
2. we will only consider the Hotels wih name of the place included for proper analysis, exclusing the address of the hotel
3. Analysing the first 3 hotels is enough considering time and effort and then make certain Business Conclusions about creating a proper customer experience and service design

'''
# Out:
# "\nAssumptions:\n1. more words in the positive and the negative coloumns the better, since they're almost legitimate\n2. we will only consider the Hotels wih name of the place included for proper analysis, exclusing the address of the hotel\n3. Analysing the first 3 hotels is enough considering time and effort and then make certain Business Conclusions about creating a proper customer experience and service design\n\n"

# %% [markdown]
# #### dropping the negative reviews with less words

# %%
final_df['negative_length'] = list(map(lambda x: len(str(x).split()), final_df['negative_review']))

# %%
final_df['positive_length'] = list(map(lambda x: len(str(x).split()), final_df['positive_review']))

# %%
final_df.head()
# Out:
#     hotel_name                                    negative_review  \
# 0  Hotel Arena   I am so angry that i made this post available...
# 1  Hotel Arena                                        No Negative
# 2  Hotel Arena   Rooms are nice but for elderly a bit difficul...
# 3  Hotel Arena   My room was dirty and I was afraid to walk ba...
# 4  Hotel Arena   You When I booked with your company on line y...
#
#                                      positive_review  \
# 0   Only the park outside of the hotel was beauti...
# 1   No real complaints the hotel was great great ...
# 2   Location was good and staff were ok It is cut...
# 3   Great location in nice surroundings the bar a...
# 4    Amazing location and building Romantic setting
#
#                                                 tags  average_score  \
# 0  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 1  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
# 2  [' Leisure trip ', ' Family with young childre...              8
# 3  [' Leisure trip ', ' Solo traveler ', ' Duplex...              8
# 4  [' Leisure trip ', ' Couple ', ' Suite ', ' St...              8
#
#    negative_length  positive_length
# 0              395                9
# 1                2              103
# 2               40               19
# 3              208               24
# 4              138                6

# %%
final_df.shape
# Out:
# (515673, 7)

# %%
sns.displot(final_df['negative_length'])

# %%
sns.displot(final_df['positive_length'])

# %%
final_df['positive_length'].describe()
# Out:
# count    515673.000000
# mean         16.466718
# std          21.463086
# min           0.000000
# 25%           4.000000
# 50%          10.000000
# 75%          21.000000
# max         393.000000
# Name: positive_length, dtype: float64

# %%
final_df['negative_length'].describe()
# Out:
# count    515673.000000
# mean         17.846649
# std          29.050175
# min           0.000000
# 25%           2.000000
# 50%           7.000000
# 75%          22.000000
# max         406.000000
# Name: negative_length, dtype: float64

# %% [markdown]
# Intuitivelly, we can consider short reviews as totally useless because they are not properly justified and they can misslead the model.
#
# According to the median length, a reasonable guess will be to filter out reviews for which the length is smaller than the median.

# %%
positive_median = final_df['positive_length'].median()
positive_median
# Out:
# 10.0

# %%
negative_median = final_df['negative_length'].median()
negative_median
# Out:
# 7.0

# %%
final_df = final_df[(final_df['positive_length'] > positive_median) & (final_df['negative_length'] > negative_median) ]
final_df.shape
# Out:
# (126738, 7)

# %%
final_df.head()
# Out:
#     hotel_name                                    negative_review  \
# 2  Hotel Arena   Rooms are nice but for elderly a bit difficul...
# 3  Hotel Arena   My room was dirty and I was afraid to walk ba...
# 5  Hotel Arena   Backyard of the hotel is total mess shouldn t...
# 6  Hotel Arena   Cleaner did not change our sheet and duvet ev...
# 7  Hotel Arena   Apart from the price for the brekfast Everyth...
#
#                                      positive_review  \
# 2   Location was good and staff were ok It is cut...
# 3   Great location in nice surroundings the bar a...
# 5   Good restaurant with modern design great chil...
# 6   The room is spacious and bright The hotel is ...
# 7   Good location Set in a lovely park friendly s...
#
#                                                 tags  average_score  \
# 2  [' Leisure trip ', ' Family with young childre...              8
# 3  [' Leisure trip ', ' Solo traveler ', ' Duplex...              8
# 5  [' Leisure trip ', ' Group ', ' Duplex Double ...              8
# 6  [' Leisure trip ', ' Group ', ' Duplex Twin Ro...              8
# 7  [' Leisure trip ', ' Couple ', ' Duplex Double...              8
#
#    negative_length  positive_length
# 2               40               19
# 3              208               24
# 5               15               18
# 6               31               16
# 7               10               17

# %%
final_df.tail()
# Out:
#                    hotel_name  \
# 515689  Atlantis Hotel Vienna
# 515704  Atlantis Hotel Vienna
# 515705  Atlantis Hotel Vienna
# 515714  Atlantis Hotel Vienna
# 515727  Atlantis Hotel Vienna
#
#                                           negative_review  \
# 515689            The net was slow The ac was not cooling
# 515704   Austrians have the good idea to do road works...
# 515705   The room is nice but without some hommy touches
# 515714   Staff not always at reception and had to wait...
# 515727         Wifi Location No tea or coffee in the room
#
#                                           positive_review  \
# 515689   The breakfast was excellent The staff were ve...
# 515704   Very easy to come back from the city center w...
# 515705   The hotel is really close to the stadhall rel...
# 515714   The nice and friendly staff who were always h...
# 515727   Rather cheap and not to far away from the cen...
#
#                                                      tags  average_score  \
# 515689  [' Leisure trip ', ' Family with young childre...              8
# 515704  [' Leisure trip ', ' Group ', ' Standard Doubl...              8
# 515705  [' Leisure trip ', ' Couple ', ' Standard Doub...              8
# 515714  [' Leisure trip ', ' Family with older childre...              8
# 515727  [' Leisure trip ', ' Couple ', ' Standard Doub...              8
#
#         negative_length  positive_length
# 515689                9               11
# 515704               13               15
# 515705                9               16
# 515714               14               12
# 515727                9               14

# %%
final_df.to_csv("cleaned_hotel_reviews.csv", sep='\t')

# %% [markdown]
# code sources:
# * https://stackoverflow.com/questions/13851535/how-to-delete-rows-from-a-pandas-dataframe-based-on-a-conditional-expression
# * https://stackoverflow.com/questions/37084812/how-to-remove-decimal-points-in-pandas
# * https://stackoverflow.com/questions/21291259/convert-floats-to-ints-in-pandas
